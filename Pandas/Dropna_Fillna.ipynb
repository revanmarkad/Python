# %% [markdown]
# # DROPNA FILLNA

# %%
import pandas as pd

csv=pd.read_csv("Country.csv",encoding='ISO-8859-1')
print(csv)
# Out:
#     Unnamed: 0         Country  Population Country Code  \
# 0          0.0   United States   331002651           US
# 1          1.0           China  1439323776           CN
# 2          2.0           India  1380004385           IN
# 3          3.0          Brazil   212559417           BR
# 4          4.0        Pakistan   220892340           PK
# 5          5.0       Indonesia   273523615           ID
# 6          6.0         Nigeria   206139589           NG
# 7          7.0      Bangladesh   164689383           BD
# 8          8.0          Russia   145934462           RU
# 9          9.0          Mexico   128932753           MX
# 10        10.0           Japan   126476461           JP
# 11        11.0        Ethiopia   114963588           ET
# 12        12.0     Philippines   109581078           PH
# 13        13.0           Egypt   102334404           EG
# 14        14.0         Vietnam    97338579           VN
# 15        15.0        DR Congo    89561404           CD
# ...

# %%
csv.dropna()
# Out:
#     Unnamed: 0         Country  Population Country Code  \
# 0          0.0   United States   331002651           US
# 1          1.0           China  1439323776           CN
# 2          2.0           India  1380004385           IN
# 3          3.0          Brazil   212559417           BR
# 4          4.0        Pakistan   220892340           PK
# 5          5.0       Indonesia   273523615           ID
# 6          6.0         Nigeria   206139589           NG
# 7          7.0      Bangladesh   164689383           BD
# 8          8.0          Russia   145934462           RU
# 9          9.0          Mexico   128932753           MX
# 10        10.0           Japan   126476461           JP
# 11        11.0        Ethiopia   114963588           ET
# 12        12.0     Philippines   109581078           PH
# 13        13.0           Egypt   102334404           EG
# 14        14.0         Vietnam    97338579           VN
# 15        15.0        DR Congo    89561404           CD
# ...

# %%
b=csv.dropna(subset=['Population'])
print(b)
# Out:
#     Unnamed: 0         Country  Population Country Code  \
# 0          0.0   United States   331002651           US
# 1          1.0           China  1439323776           CN
# 2          2.0           India  1380004385           IN
# 3          3.0          Brazil   212559417           BR
# 4          4.0        Pakistan   220892340           PK
# 5          5.0       Indonesia   273523615           ID
# 6          6.0         Nigeria   206139589           NG
# 10        10.0           Japan   126476461           JP
# 11        11.0        Ethiopia   114963588           ET
# 12        12.0     Philippines   109581078           PH
# 13        13.0           Egypt   102334404           EG
# 14        14.0         Vietnam    97338579           VN
# 15        15.0        DR Congo    89561404           CD
# 18        18.0         Germany    83783942           DE
# 19        19.0        Thailand    69799978           TH
# 20        20.0  United Kingdom    67886011           GB
# ...

# %%
a=csv.dropna(inplace=True)
print(a)
# Out:
# None

# %% [markdown]
# # fillna

# %%
m=csv.fillna({"National Anthem":"REVAN"})
print(m)
# Out:
#     Unnamed: 0         Country  Population Country Code  \
# 0          0.0   United States   331002651           US
# 1          1.0           China  1439323776           CN
# 2          2.0           India  1380004385           IN
# 3          3.0          Brazil   212559417           BR
# 4          4.0        Pakistan   220892340           PK
# 5          5.0       Indonesia   273523615           ID
# 6          6.0         Nigeria   206139589           NG
# 7          7.0      Bangladesh   164689383           BD
# 8          8.0          Russia   145934462           RU
# 9          9.0          Mexico   128932753           MX
# 10        10.0           Japan   126476461           JP
# 11        11.0        Ethiopia   114963588           ET
# 12        12.0     Philippines   109581078           PH
# 13        13.0           Egypt   102334404           EG
# 14        14.0         Vietnam    97338579           VN
# 15        15.0        DR Congo    89561404           CD
# ...

# %%
 n=csv.fillna(method="ffill")
print(n)
# Out:
#     Unnamed: 0         Country  Population Country Code  \
# 0          0.0   United States   331002651           US
# 1          1.0           China  1439323776           CN
# 2          2.0           India  1380004385           IN
# 3          3.0          Brazil   212559417           BR
# 4          4.0        Pakistan   220892340           PK
# 5          5.0       Indonesia   273523615           ID
# 6          6.0         Nigeria   206139589           NG
# 10        10.0           Japan   126476461           JP
# 11        11.0        Ethiopia   114963588           ET
# 12        12.0     Philippines   109581078           PH
# 13        13.0           Egypt   102334404           EG
# 14        14.0         Vietnam    97338579           VN
# 15        15.0        DR Congo    89561404           CD
# 18        18.0         Germany    83783942           DE
# 19        19.0        Thailand    69799978           TH
# 20        20.0  United Kingdom    67886011           GB
# ...
