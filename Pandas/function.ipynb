# %% [markdown]
# # Pandas function

# %%
import pandas as pd

csv_1=pd.read_csv("Country.csv")
print(csv_1)
# Out:
#     Unnamed: 0         Country  Population Country Code  \
# 0            0   United States   331002651           US
# 1            1           China  1439323776           CN
# 2            2           India  1380004385           IN
# 3            3          Brazil   212559417           BR
# 4            4        Pakistan   220892340           PK
# 5            5       Indonesia   273523615           ID
# 6            6         Nigeria   206139589           NG
# 7            7      Bangladesh   164689383           BD
# 8            8          Russia   145934462           RU
# 9            9          Mexico   128932753           MX
# 10          10           Japan   126476461           JP
# 11          11        Ethiopia   114963588           ET
# 12          12     Philippines   109581078           PH
# 13          13           Egypt   102334404           EG
# 14          14         Vietnam    97338579           VN
# 15          15        DR Congo    89561404           CD
# ...

# %%
csv_1.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
csv_1.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Population', 'Country Code',
#        'National Anthem'],
#       dtype='object')

# %%
csv_1.describe()
# Out:
#        Unnamed: 0    Population
# count    49.00000  4.900000e+01
# mean     24.00000  1.374842e+08
# std      14.28869  2.734940e+08
# min       0.00000  2.913681e+07
# 25%      12.00000  3.892835e+07
# 50%      24.00000  5.930869e+07
# 75%      36.00000  1.095811e+08
# max      48.00000  1.439324e+09

# %%
csv_1.head(10)
# Out:
#    Unnamed: 0        Country  Population Country Code  \
# 0           0  United States   331002651           US
# 1           1          China  1439323776           CN
# 2           2          India  1380004385           IN
# 3           3         Brazil   212559417           BR
# 4           4       Pakistan   220892340           PK
# 5           5      Indonesia   273523615           ID
# 6           6        Nigeria   206139589           NG
# 7           7     Bangladesh   164689383           BD
# 8           8         Russia   145934462           RU
# 9           9         Mexico   128932753           MX
#
#                           National Anthem
# 0                The Star-Spangled Banner
# 1                 March of the Volunteers
# 2                          Jana Gana Mana
# 3                Hino Nacional Brasileiro
# 4                   Pak Sarzamin Shad Bad
# 5                          Indonesia Raya
# 6                    Arise, O Compatriots
# ...

# %%
csv_1.tail(4)
# Out:
#     Unnamed: 0     Country  Population Country Code  \
# 45          45  Mozambique    31255435           MZ
# 46          46       Ghana    31072940           GH
# 47          47       Yemen    29825968           YE
# 48          48       Nepal    29136808           NP
#
#                  National Anthem
# 45                  Pátria Amada
# 46  God Bless Our Homeland Ghana
# 47          النشيد الوطني اليمني
# 48         सयौं थुँगा फूलका हामी

# %%
csv_1[16:21]
# Out:
#     Unnamed: 0         Country  Population Country Code  \
# 16          16          Turkey    84339067           TR
# 17          17            Iran    83992949           IR
# 18          18         Germany    83783942           DE
# 19          19        Thailand    69799978           TH
# 20          20  United Kingdom    67886011           GB
#
#                               National Anthem
# 16                             İstiklal Marşı
# 17  Sorood-e Melli-e Jomhouri-e Eslami-e Iran
# 18                            Deutschlandlied
# 19                           Phleng Chat Thai
# 20                         God Save the Queen

# %%
print(type(csv_1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
csv_1.to_numpy()
# Out:
# array([[0, 'United States', 331002651, 'US', 'The Star-Spangled Banner'],
#        [1, 'China', 1439323776, 'CN', 'March of the Volunteers'],
#        [2, 'India', 1380004385, 'IN', 'Jana Gana Mana'],
#        [3, 'Brazil', 212559417, 'BR', 'Hino Nacional Brasileiro'],
#        [4, 'Pakistan', 220892340, 'PK', 'Pak Sarzamin Shad Bad'],
#        [5, 'Indonesia', 273523615, 'ID', 'Indonesia Raya'],
#        [6, 'Nigeria', 206139589, 'NG', 'Arise, O Compatriots'],
#        [7, 'Bangladesh', 164689383, 'BD', 'Amar Shonar Bangla'],
#        [8, 'Russia', 145934462, 'RU',
#         'State Anthem of the Russian Federation'],
#        [9, 'Mexico', 128932753, 'MX', 'Himno Nacional Mexicano'],
#        [10, 'Japan', 126476461, 'JP', 'Kimigayo'],
#        [11, 'Ethiopia', 114963588, 'ET', 'Ethiopia, Be Happy!'],
#        [12, 'Philippines', 109581078, 'PH', 'Lupang Hinirang'],
#        [13, 'Egypt', 102334404, 'EG', 'Bilady, Bilady, Bilady'],
# ...

# %%
import numpy as np

v=np.asarray(csv_1)
print(v)
# Out:
# [[0 'United States' 331002651 'US' 'The Star-Spangled Banner']
#  [1 'China' 1439323776 'CN' 'March of the Volunteers']
#  [2 'India' 1380004385 'IN' 'Jana Gana Mana']
#  [3 'Brazil' 212559417 'BR' 'Hino Nacional Brasileiro']
#  [4 'Pakistan' 220892340 'PK' 'Pak Sarzamin Shad Bad']
#  [5 'Indonesia' 273523615 'ID' 'Indonesia Raya']
#  [6 'Nigeria' 206139589 'NG' 'Arise, O Compatriots']
#  [7 'Bangladesh' 164689383 'BD' 'Amar Shonar Bangla']
#  [8 'Russia' 145934462 'RU' 'State Anthem of the Russian Federation']
#  [9 'Mexico' 128932753 'MX' 'Himno Nacional Mexicano']
#  [10 'Japan' 126476461 'JP' 'Kimigayo']
#  [11 'Ethiopia' 114963588 'ET' 'Ethiopia, Be Happy!']
#  [12 'Philippines' 109581078 'PH' 'Lupang Hinirang']
#  [13 'Egypt' 102334404 'EG' 'Bilady, Bilady, Bilady']
#  [14 'Vietnam' 97338579 'VN' 'Tiến Quân Ca']
#  [15 'DR Congo' 89561404 'CD' 'Debout Congolais']
#  [16 'Turkey' 84339067 'TR' 'İstiklal Marşı']
# ...

# %%
csv_1.sort_index(axis=0,ascending=False)
# Out:
#     Unnamed: 0         Country  Population Country Code  \
# 48          48           Nepal    29136808           NP
# 47          47           Yemen    29825968           YE
# 46          46           Ghana    31072940           GH
# 45          45      Mozambique    31255435           MZ
# 44          44        Malaysia    32365999           MY
# 43          43          Angola    32866272           AO
# 42          42            Peru    32971854           PE
# 41          41      Uzbekistan    33469203           UZ
# 40          40    Saudi Arabia    34813871           SA
# 39          39         Morocco    36910560           MA
# 38          38          Canada    37742154           CA
# 37          37          Poland    37846611           PL
# 36          36     Afghanistan    38928346           AF
# 35          35            Iraq    40222493           IQ
# 34          34         Ukraine    43733762           UA
# 33          33           Sudan    43849260           SD
# ...

# %%
csv_1['Population'][3]=866923
print(csv_1)
# Out:
#     Unnamed: 0         Country  Population Country Code  \
# 0            0   United States   331002651           US
# 1            1           China  1439323776           CN
# 2            2           India  1380004385           IN
# 3            3          Brazil      866923           BR
# 4            4        Pakistan   220892340           PK
# 5            5       Indonesia   273523615           ID
# 6            6         Nigeria   206139589           NG
# 7            7      Bangladesh   164689383           BD
# 8            8          Russia   145934462           RU
# 9            9          Mexico   128932753           MX
# 10          10           Japan   126476461           JP
# 11          11        Ethiopia   114963588           ET
# 12          12     Philippines   109581078           PH
# 13          13           Egypt   102334404           EG
# 14          14         Vietnam    97338579           VN
# 15          15        DR Congo    89561404           CD
# ...

# %%
csv_1.loc[10,"Population"]=1264764628
print(csv_1.iloc[10])
# Out:
# Unnamed: 0                 10
# Country                 Japan
# Population         1264764628
# Country Code               JP
# National Anthem      Kimigayo
# Name: 10, dtype: object

# %%
csv_1.loc[[10],["Population"]]
# Out:
#     Population
# 10  1264764628

# %%
csv_1.drop("Unnamed: 0",axis=1)
# Out:
#            Country  Population Country Code  \
# 0    United States   331002651           US
# 1            China  1439323776           CN
# 2            India  1380004385           IN
# 3           Brazil      866923           BR
# 4         Pakistan   220892340           PK
# 5        Indonesia   273523615           ID
# 6          Nigeria   206139589           NG
# 7       Bangladesh   164689383           BD
# 8           Russia   145934462           RU
# 9           Mexico   128932753           MX
# 10           Japan  1264764628           JP
# 11        Ethiopia   114963588           ET
# 12     Philippines   109581078           PH
# 13           Egypt   102334404           EG
# 14         Vietnam    97338579           VN
# 15        DR Congo    89561404           CD
# 16          Turkey    84339067           TR
# 17            Iran    83992949           IR
# 18         Germany    83783942           DE
# 19        Thailand    69799978           TH
# ...
